# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  302.096679688
# Nearest to th: begging, riga, serviced, faced, kaf, marksmanship, bartholomew, suarez,
# Nearest to new: rumors, peta, nemesis, determinism, peirce, aml, tijuana, casas,
# Nearest to by: beatle, angers, bien, bell, motorcyclist, unsustainable, tombs, impart,
# Nearest to some: graciously, signed, consequent, evacuate, voluntarily, deuteronomic, tum, fulfil,
# Nearest to with: centromere, bakker, aman, scranton, croix, iblis, traveled, bacon,
# Nearest to zero: consular, crickets, fick, xbox, claypool, afterward, bari, lacrosse,
# Nearest to has: frontal, midfielder, perspectives, spy, nanosystems, robeson, larnaca, reins,
# Nearest to years: disjunction, biophysics, semper, evicted, obese, umbilical, leaders, tired,
# Nearest to use: iib, lantau, asch, kearney, penance, chadian, clocked, legalize,
# Nearest to first: hedonism, exceptionally, berkley, troop, glucose, kabul, instituting, infinitesimals,
# Nearest to over: qed, neighbourhoods, fetuses, destabilization, cabinda, niebuhr, livestock, chartered,
# Nearest to also: aniston, microeconomics, qinghai, procurement, cant, staffed, executors, wipe,
# Nearest to united: dozens, nabataean, valhalla, hamlets, rudder, tasmania, tallis, required,
# Nearest to that: archeology, buttons, censuses, viscous, indexing, tattooing, telegraph, charterers,
# Nearest to a: schr, rann, chimpanzee, cytokinesis, delhi, manila, assortment, mithraeum,
# Nearest to world: mona, colonialism, vacuole, genscher, definitions, superorder, conformation, customer,
# Average loss at step  2000 :  113.551891292
# Average loss at step  4000 :  52.5259267178
# Average loss at step  6000 :  33.5058006217
# Average loss at step  8000 :  23.5742713878
# Average loss at step  10000 :  17.8291874733
# Nearest to th: one, two, archie, fao, var, begging, touch, zero,
# Nearest to new: rumors, submitted, legends, complicated, scholarships, house, footage, t,
# Nearest to by: in, of, and, as, UNK, altenberg, scripts, that,
# Nearest to some: lincoln, signed, schopenhauer, text, coined, cool, a, his,
# Nearest to with: and, in, austin, bckgr, average, boyle, is, drunken,
# Nearest to zero: nine, archie, one, eight, gb, seven, austin, six,
# Nearest to has: was, frontal, perspectives, robeson, is, notes, crater, to,
# Nearest to years: leaders, aspects, earned, prejudice, holland, finished, pueblo, chile,
# Nearest to use: gland, austin, commerce, archie, buildings, zones, yeast, lutheran,
# Nearest to first: hogeschool, var, gland, devices, archie, anthology, australian, berkley,
# Nearest to over: in, ayers, athabasca, cabinda, chartered, chief, regardless, publication,
# Nearest to also: orthodox, schopenhauer, biscuit, generally, eichmann, archie, boards, bulk,
# Nearest to united: required, molinari, dozens, austin, mya, annexation, charity, gland,
# Nearest to that: and, by, boards, this, djs, sports, archeology, telegraph,
# Nearest to a: the, UNK, archie, bckgr, and, shoot, austin, this,
# Nearest to world: definitions, superorder, colonialism, canals, austin, conformation, mona, alif,
# Average loss at step  12000 :  14.2197046857
# Average loss at step  14000 :  11.7984050034
# Average loss at step  16000 :  9.87926309168
# Average loss at step  18000 :  8.33270274282
# Average loss at step  20000 :  8.15293144691
# Nearest to th: one, operatorname, two, venn, minster, newsgroups, antwerp, five,
# Nearest to new: submitted, rumors, alcott, desolate, legends, complicated, scholarships, orpheus,
# Nearest to by: in, peptide, for, as, and, operatorname, was, is,
# Nearest to some: the, dasyprocta, his, apl, lincoln, signed, cool, an,
# Nearest to with: and, in, for, by, circ, dasyprocta, after, is,
# Nearest to zero: nine, eight, five, seven, six, four, three, circ,
# Nearest to has: was, is, had, perspectives, aleuts, audiogalaxy, frontal, crater,
# Nearest to years: leaders, aspects, five, truetype, xxvii, operatorname, earned, ulyanov,
# Nearest to use: gland, austin, agouti, dasyprocta, commerce, nickname, zones, penance,
# Nearest to first: friars, hogeschool, var, anthology, gland, troop, australian, eva,
# Nearest to over: in, chartered, truetype, ayers, suffixes, cabinda, athabasca, albertus,
# Nearest to also: which, generally, schopenhauer, who, orthodox, biscuit, archie, lottery,
# Nearest to united: nabataean, required, tasmania, charity, dozens, gi, annexation, judicial,
# Nearest to that: which, and, this, gollancz, it, boards, sports, djs,
# Nearest to a: the, circ, dasyprocta, agouti, archie, operatorname, this, shoot,
# Nearest to world: definitions, superorder, canals, colonialism, truetype, mona, conformation, alif,
# Average loss at step  22000 :  6.99769794512
# Average loss at step  24000 :  6.85490633821
# Average loss at step  26000 :  6.75393118834
# Average loss at step  28000 :  6.30287480891
# Average loss at step  30000 :  5.9561396296
# Nearest to th: one, two, venn, newsgroups, minster, five, zero, six,
# Nearest to new: submitted, rumors, alcott, desolate, vojt, complicated, legends, dasyprocta,
# Nearest to by: in, peptide, was, as, from, operatorname, for, with,
# Nearest to some: the, his, dasyprocta, apl, its, mood, cool, floppy,
# Nearest to with: in, for, and, by, after, circ, dasyprocta, arin,
# Nearest to zero: eight, six, five, nine, seven, four, three, agouti,
# Nearest to has: is, was, had, have, aleuts, audiogalaxy, perspectives, shrunk,
# Nearest to years: five, leaders, aspects, four, xxvii, disjunction, prejudice, truetype,
# Nearest to use: commerce, gland, dasyprocta, nickname, agouti, abet, zones, penance,
# Nearest to first: friars, hogeschool, var, speedup, eva, gland, anthology, dasyprocta,
# Nearest to over: chartered, in, truetype, albertus, hamas, ayers, exception, suffixes,
# Nearest to also: which, generally, not, who, it, that, schopenhauer, benzene,
# Nearest to united: nabataean, gi, tasmania, charity, annexation, required, cracks, restaurant,
# Nearest to that: which, this, it, gollancz, explorer, pharisees, but, and,
# Nearest to a: the, circ, dasyprocta, agouti, arin, this, operatorname, shoot,
# Nearest to world: definitions, superorder, mona, canals, colonialism, truetype, conformation, spots,
# Average loss at step  32000 :  5.95614952338
# Average loss at step  34000 :  5.63015833116
# Average loss at step  36000 :  5.77715979433
# Average loss at step  38000 :  5.57880888605
# Average loss at step  40000 :  5.25447151756
# Nearest to th: six, eight, five, three, four, two, zero, venn,
# Nearest to new: submitted, rumors, desolate, kifl, alcott, dasyprocta, legends, vojt,
# Nearest to by: was, peptide, in, operatorname, with, and, recitative, from,
# Nearest to some: many, the, dasyprocta, their, its, mood, both, apl,
# Nearest to with: and, for, in, dasyprocta, by, arin, circ, through,
# Nearest to zero: eight, five, seven, nine, six, agouti, four, circ,
# Nearest to has: had, was, is, have, audiogalaxy, offenders, archie, eight,
# Nearest to years: leaders, aspects, five, four, prejudice, seven, truetype, xxvii,
# Nearest to use: commerce, dasyprocta, gland, nickname, agouti, abet, recitative, zones,
# Nearest to first: friars, hogeschool, var, anthology, speedup, gland, reliant, agouti,
# Nearest to over: chartered, albertus, in, truetype, ayers, hamas, suffixes, exception,
# Nearest to also: which, generally, who, not, that, it, archie, benzene,
# Nearest to united: nabataean, gi, tasmania, annexation, cracks, charity, judicial, venerable,
# Nearest to that: which, this, it, but, kifl, where, also, djs,
# Nearest to a: the, dasyprocta, circ, agouti, kifl, operatorname, archie, agp,
# Nearest to world: definitions, superorder, mona, canals, colonialism, conformation, truetype, merovingian,
# Average loss at step  42000 :  5.38484623659
# Average loss at step  44000 :  5.2688941133
# Average loss at step  46000 :  5.28808410692
# Average loss at step  48000 :  5.22802318954
# Average loss at step  50000 :  4.99969934428
# Nearest to th: six, three, five, eight, four, one, zero, venn,
# Nearest to new: submitted, kifl, rumors, desolate, legends, pharmacology, alcott, dasyprocta,
# Nearest to by: was, in, peptide, as, be, with, is, for,
# Nearest to some: many, both, these, dasyprocta, its, their, mood, apl,
# Nearest to with: in, and, for, by, or, after, circ, arin,
# Nearest to zero: eight, seven, six, five, nine, four, three, kapoor,
# Nearest to has: had, is, was, have, archie, audiogalaxy, offenders, rocket,
# Nearest to years: four, leaders, aspects, prejudice, seven, presumption, six, pueblo,
# Nearest to use: commerce, dasyprocta, gland, nickname, agouti, abet, zones, recitative,
# Nearest to first: hogeschool, second, friars, reliant, var, speedup, anthology, gland,
# Nearest to over: chartered, three, albertus, four, truetype, hamas, in, kapoor,
# Nearest to also: which, generally, not, who, that, it, benzene, often,
# Nearest to united: nabataean, judicial, venerable, cracks, gi, tasmania, charity, annexation,
# Nearest to that: which, this, but, where, it, djs, explorer, gollancz,
# Nearest to a: the, circ, dasyprocta, kifl, agouti, or, operatorname, this,
# Nearest to world: definitions, gundam, superorder, colonialism, mona, conformation, truetype, canals,
# Average loss at step  52000 :  5.02794779158
# Average loss at step  54000 :  5.19501383412
# Average loss at step  56000 :  5.06711629927
# Average loss at step  58000 :  5.04194260967
# Average loss at step  60000 :  4.95949848402
# Nearest to th: six, eight, five, zero, seven, german, venn, minster,
# Nearest to new: kifl, desolate, submitted, pharmacology, dasyprocta, rumors, orpheus, michelob,
# Nearest to by: was, be, peptide, operatorname, after, as, triad, for,
# Nearest to some: many, these, both, their, all, its, dasyprocta, wct,
# Nearest to with: in, ursus, for, between, dasyprocta, by, and, circ,
# Nearest to zero: six, eight, five, seven, nine, four, ursus, agouti,
# Nearest to has: had, is, was, have, archie, audiogalaxy, rocket, yet,
# Nearest to years: four, leaders, six, aspects, ursus, prejudice, presumption, five,
# Nearest to use: commerce, nickname, dasyprocta, michelob, gland, agouti, abet, microbats,
# Nearest to first: second, michelob, friars, hogeschool, reliant, speedup, var, agouti,
# Nearest to over: chartered, four, truetype, hamas, albertus, kapoor, since, six,
# Nearest to also: which, generally, who, wct, not, that, archie, originally,
# Nearest to united: nabataean, ursus, judicial, cracks, venerable, gi, annexation, ngc,
# Nearest to that: which, this, but, wct, where, it, however, djs,
# Nearest to a: the, circ, dasyprocta, ursus, kifl, agouti, any, this,
# Nearest to world: definitions, gundam, michelob, superorder, mona, conformation, colonialism, truetype,
# Average loss at step  62000 :  5.0137830652
# Average loss at step  64000 :  4.83651320499
# Average loss at step  66000 :  4.59099116814
# Average loss at step  68000 :  4.98557839763
# Average loss at step  70000 :  4.87903848886
# Nearest to th: six, eight, three, seven, five, four, nine, minster,
# Nearest to new: kifl, desolate, submitted, pharmacology, orpheus, rumors, dasyprocta, legends,
# Nearest to by: was, peptide, be, operatorname, with, after, triad, through,
# Nearest to some: many, these, both, all, their, the, dasyprocta, several,
# Nearest to with: between, ursus, and, in, by, for, at, dasyprocta,
# Nearest to zero: five, eight, six, seven, nine, four, three, ursus,
# Nearest to has: had, have, was, is, archie, audiogalaxy, upanija, eight,
# Nearest to years: four, six, leaders, five, ursus, aspects, eight, liberation,
# Nearest to use: commerce, nickname, dasyprocta, michelob, agouti, cebus, gland, abet,
# Nearest to first: second, hogeschool, michelob, friars, reliant, last, speedup, var,
# Nearest to over: chartered, albertus, thaler, hamas, since, truetype, into, niebuhr,
# Nearest to also: which, generally, who, often, not, originally, wct, koruna,
# Nearest to united: nabataean, cebus, ursus, venerable, thaler, judicial, cracks, annexation,
# Nearest to that: which, this, wct, where, but, microcebus, it, djs,
# Nearest to a: the, circ, dasyprocta, kifl, ursus, agouti, operatorname, agp,
# Nearest to world: mitral, definitions, gundam, superorder, michelob, navy, mona, asin,
# Average loss at step  72000 :  4.75085742295
# Average loss at step  74000 :  4.80629957378
# Average loss at step  76000 :  4.73817293251
# Average loss at step  78000 :  4.78274543083
# Average loss at step  80000 :  4.79942565072
# Nearest to th: six, seven, five, eight, serviced, minster, venn, four,
# Nearest to new: kifl, submitted, desolate, pharmacology, orpheus, michelob, dasyprocta, legends,
# Nearest to by: was, peptide, be, through, operatorname, michelob, when, recitative,
# Nearest to some: many, these, both, all, several, their, dasyprocta, wct,
# Nearest to with: between, in, ursus, and, circ, for, seven, by,
# Nearest to zero: five, four, six, eight, seven, nine, agouti, ursus,
# Nearest to has: had, have, was, is, archie, upanija, audiogalaxy, offenders,
# Nearest to years: six, aspects, ursus, leaders, four, liberation, presumption, evicted,
# Nearest to use: commerce, nickname, dasyprocta, michelob, penance, agouti, projections, abet,
# Nearest to first: second, last, michelob, reliant, hogeschool, friars, var, during,
# Nearest to over: chartered, thaler, albertus, hamas, since, truetype, kapoor, lemmy,
# Nearest to also: which, generally, often, usually, now, who, originally, koruna,
# Nearest to united: nabataean, cordilleras, cebus, venerable, ursus, judicial, cracks, gi,
# Nearest to that: which, this, wct, but, however, microcebus, where, pontificia,
# Nearest to a: the, circ, dasyprocta, ursus, kifl, agouti, operatorname, any,
# Nearest to world: mitral, definitions, gundam, superorder, michelob, truetype, conformation, mona,
# Average loss at step  82000 :  4.76885705078
# Average loss at step  84000 :  4.76345424008
# Average loss at step  86000 :  4.76369976985
# Average loss at step  88000 :  4.73759759486
# Average loss at step  90000 :  4.72387017834
# Nearest to th: six, five, eight, seven, nine, four, zero, minster,
# Nearest to new: kifl, michelob, submitted, pharmacology, dasyprocta, desolate, orpheus, alcott,
# Nearest to by: peptide, was, through, operatorname, be, as, in, from,
# Nearest to some: many, these, both, several, all, the, their, dasyprocta,
# Nearest to with: between, in, ursus, circ, for, and, after, through,
# Nearest to zero: five, eight, six, seven, four, nine, kapoor, three,
# Nearest to has: had, have, was, is, archie, upanija, audiogalaxy, offenders,
# Nearest to years: aspects, knuckles, leaders, liberation, seven, evicted, ursus, globemaster,
# Nearest to use: commerce, globemaster, nickname, dasyprocta, michelob, abet, cebus, agouti,
# Nearest to first: second, last, michelob, friars, reliant, hogeschool, globemaster, var,
# Nearest to over: chartered, into, hamas, thaler, truetype, albertus, kapoor, preaching,
# Nearest to also: which, generally, often, now, not, usually, who, originally,
# Nearest to united: nabataean, cordilleras, cebus, ursus, venerable, judicial, cracks, thaler,
# Nearest to that: which, however, but, this, wct, where, pontificia, it,
# Nearest to a: the, circ, dasyprocta, globemaster, agouti, kifl, any, ursus,
# Nearest to world: mitral, definitions, superorder, gundam, michelob, mona, navy, asin,
# Average loss at step  92000 :  4.65896133614
# Average loss at step  94000 :  4.73809877753
# Average loss at step  96000 :  4.68109809864
# Average loss at step  98000 :  4.60234310257
# Average loss at step  100000 :  4.69431320643
# Nearest to th: six, nine, minster, serviced, eight, seven, venn, german,
# Nearest to new: kifl, pharmacology, submitted, desolate, orpheus, programme, alcott, michelob,
# Nearest to by: peptide, was, through, be, operatorname, when, as, michelob,
# Nearest to some: many, these, both, several, all, their, dasyprocta, this,
# Nearest to with: between, in, circ, ursus, after, through, for, arin,
# Nearest to zero: eight, five, seven, nine, four, six, three, agouti,
# Nearest to has: had, have, was, is, archie, audiogalaxy, offenders, upanija,
# Nearest to years: aspects, knuckles, liberation, leaders, months, presumption, evicted, five,
# Nearest to use: globemaster, nickname, dasyprocta, commerce, michelob, cebus, abet, ursus,
# Nearest to first: second, last, michelob, reliant, friars, globemaster, hogeschool, anthology,
# Nearest to over: chartered, hamas, into, four, thaler, truetype, within, superstardom,
# Nearest to also: which, often, generally, now, usually, not, still, originally,
# Nearest to united: nabataean, cordilleras, psionic, cebus, venerable, ursus, cracks, judicial,
# Nearest to that: which, this, however, wct, but, where, microcebus, pontificia,
# Nearest to a: the, circ, dasyprocta, ursus, kifl, globemaster, behalf, any,
# Nearest to world: mitral, definitions, gundam, michelob, superorder, truetype, navy, surfacing,
